# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/cleaned data"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/cleaned data

# %% [markdown]
# # Total Electricity consumption per capita

# %%
df = pd.read_csv('SeriesExport-08-05-2023-11-27-49.csv')
df
# Out:
#     YEAR  ESTPP
# 0   2021   6317
# 1   2020   6333
# 2   2019   6349
# 3   2018   6472
# 4   2017   6540
# ..   ...    ...
# 57  1964   4242
# 58  1963   3935
# 59  1962   3802
# 60  1961   3782
# 61  1960   3609
#
# [62 rows x 2 columns]

# %%
import missingno
missingno.matrix(df)
# Out:
# <Axes: >

# %%
years = np.array(df['YEAR']).reshape(-1, 1)
estpp = np.array(df['ESTPP'])

# %%
polynomial_degree = 2

# %%
poly_features = PolynomialFeatures(degree=polynomial_degree)
X_poly = poly_features.fit_transform(years)

model = LinearRegression()
model.fit(X_poly, estpp)

predictions = model.predict(X_poly)

# %%
plt.scatter(years, estpp, color='blue', label='data')
plt.plot(years, predictions, color='red', label='Polynomial Regression')
plt.xlabel('Year')
plt.ylabel('Electricity per Capita')
plt.title('Polynomial Regression for Electricity per Capita')
plt.legend()
plt.show()

# %%
r2 = r2_score(estpp, predictions)
print("R-squared:", r2)
# Out:
# R-squared: 0.8398715453433083

# %% [markdown]
# # Natural Gas Cosumption per Capita

# %%
df = pd.read_csv('SeriesExport-08-05-2023-12-45-51.csv')
missingno.matrix(df)
# Out:
# <Axes: >

# %%
# SeriesExport-08-05-2023-12-45-51

years = np.array(df['YEAR']).reshape(-1, 1)
ngtpp= np.array(df['NGTPP'])
poly_features = PolynomialFeatures(degree=polynomial_degree)
X_poly = poly_features.fit_transform(years)

model = LinearRegression()
model.fit(X_poly, ngtpp)

predictions = model.predict(X_poly)

# %%
plt.scatter(years, ngtpp, color='blue', label='data')
plt.plot(years, predictions, color='red', label='Polynomial Regression')
plt.xlabel('Year')
plt.ylabel('Natural Gas per Capita')
plt.title('Polynomial Regression for Natural Gas per Capita')
plt.legend()
plt.show()

# %%
r2 = r2_score(ngtpp, predictions)
print("R-squared:", r2)
# Out:
# R-squared: 0.6900490649860277

# %% [markdown]
# # Crude oil and petroleum products consumption per Capita

# %%
df = pd.read_csv('SeriesExport-08-05-2023-13-04-50.csv')
missingno.matrix(df)
# Out:
# <Axes: >

# %%
# SeriesExport-08-05-2023-13-04-50

years = np.array(df['YEAR']).reshape(-1, 1)
patpp= np.array(df['PATPP'])
poly_features = PolynomialFeatures(degree=polynomial_degree)
X_poly = poly_features.fit_transform(years)

model = LinearRegression()
model.fit(X_poly, patpp)

predictions = model.predict(X_poly)

plt.scatter(years, patpp, color='blue', label='data')
plt.plot(years, predictions, color='red', label='Polynomial Regression')
plt.xlabel('Year')
plt.ylabel('Crude oil and petroleum products consumption per Capita')
plt.title('Polynomial Regression for Crude oil and petroleum products consumption per Capita')
plt.legend()
plt.show()

# %%
r2 = r2_score(patpp, predictions)
print("R-squared:", r2)
# Out:
# R-squared: 0.6302822214585084

# %% [markdown]
# # Polynomial Regression for Nuclear energy and Uranium usage per Capita

# %%
df = pd.read_csv('SeriesExport-08-05-2023-13-14-54.csv')
missingno.matrix(df)
# Out:
# <Axes: >

# %%
# SeriesExport-08-05-2023-13-14-54



years = np.array(df['YEAR']).reshape(-1, 1)
nuetb= np.array(df['NUETB'])
poly_features = PolynomialFeatures(degree=polynomial_degree)
X_poly = poly_features.fit_transform(years)

model = LinearRegression()
model.fit(X_poly, nuetb)

predictions = model.predict(X_poly)

plt.scatter(years, nuetb, color='blue', label='data')
plt.plot(years, predictions, color='red', label='Polynomial Regression')
plt.xlabel('Year')
plt.ylabel('Nuclear energy and Uranium usage per Capita')
plt.title('Nuclear energy and Uranium usage per Capita')
plt.legend()
plt.show()

# %%
r2 = r2_score(nuetb, predictions)
print("R-squared:", r2)
# Out:
# R-squared: 0.7364393939378155
